# %%
from sqlalchemy import create_engine
import pandas as pd
import pypyodbc as po

# %%
SERVER = 'localhost\SQLEXPRESS'
DATABASE = 'VentasDM'
DRIVER = 'SQL Server Native Client 11.0'
USERNAME = ''
PASSWORD = ''
DATABASE_CONNECTION = f'mssql://{USERNAME}:{PASSWORD}@{SERVER}/{DATABASE}?driver={DRIVER}'

# %%
engine = create_engine(DATABASE_CONNECTION)
connection = engine.connect()

# %%
data = pd.read_sql_query("select * from [VentasDM].[dbo].[Dim_Producto]", connection)

# %%
data
# Out:
#    Producto_Key  IdProducto  IdSubFamilia  IdFamilia  IdCategoria  IdRubro  \
# 0            13           1             1          1            1        1
# 1            14           2             2          2            1        1
# 2            15           3             3          3            3        4
# 3            16           4             4          4            5        2
# 4            17           5             4          4            5        2
# 5            18           5             4          4            5        2
# 6            19           6             4          4            5        2
# 7            20           7             2          2            1        1
#
#    IdSeccion          NombreProducto    NombreSubFamilia NombreFamilia  \
# 0          4  Gloria hierro y calcio       Gloria 5 años        Gloria
# 1          4  Jamonada de 13 tajadas   Jamonada de pollo         Laive
# 2          3         Lorito  Pequeño  Lorito Triple Raya          Loro
# 3          4  Cifrut Piña Granadilla              Cifrut            KR
# 4          4              Cifrut two              Cifrut            KR
# 5          4              Cifrut two              Cifrut            KR
# 6          4            Cifrut three              Cifrut            KR
# 7          4              gatito fox   Jamonada de pollo         Laive
#
#   NombreCategoria NombreRubro NombreSeccion
# 0          yogurt     Lacteos   Comestibles
# 1          yogurt     Lacteos   Comestibles
# 2        cuaderno   Escolares        Utiles
# 3         gaseosa     Bebidas   Comestibles
# 4         gaseosa     Bebidas   Comestibles
# 5         gaseosa     Bebidas   Comestibles
# 6         gaseosa     Bebidas   Comestibles
# 7          yogurt     Lacteos   Comestibles
