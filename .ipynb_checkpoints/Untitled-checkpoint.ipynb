# %%
import pandas as pd #importo libreria pandas

# %%
data=pd.ExcelFile(r'C:\Users\jesica\Downloads\Ventas+2010+-+copia.xlsx', engine='openpyxl') #agrego el archivo excel
print(data.sheet_names) #veo que hojas tiene
# Out:
# ['Datos', 'Productos']

# %%
DataFrame=data.parse('Datos') #creo el dataframe llamando al nombre de la hoja de excel que quiero ver
DataFrame2=data.parse('Productos')

# %%
print(DataFrame) #muestro los valores del dataframe
# Out:
#       SKU  ID fila  ID Orden Fecha Orden        Prioridad  Cantidad  \
# 0       1        1         3  2010-10-13             Bajo         6
# 1       2       49       293  2012-10-01             Alto        49
# 2       3       50       293  2012-10-01             Alto        27
# 3       4       80       483  2011-07-10             Alto        30
# 4       5       85       515  2010-08-28  No Especificado        19
# ...   ...      ...       ...         ...              ...       ...
# 8394  209     7765     55558  2010-08-09            Medio         8
# 8395  982     7766     55558  2010-08-09            Medio        23
# 8396  514     7906     56550  2011-04-08  No Especificado        37
# 8397  406     7907     56550  2011-04-08  No Especificado         8
# 8398  135     7914     56581  2009-02-08             Alto        20
#
#           Ventas  Descuento  Tipo de Envío   Ganancia  ...  \
# 0       261.5400       0.04  Aereo Regular  -213.2500  ...
# ...

# %%
DataFrame #ejecuta el dataframe
# Out:
#       SKU  ID fila  ID Orden Fecha Orden        Prioridad  Cantidad  \
# 0       1        1         3  2010-10-13             Bajo         6
# 1       2       49       293  2012-10-01             Alto        49
# 2       3       50       293  2012-10-01             Alto        27
# 3       4       80       483  2011-07-10             Alto        30
# 4       5       85       515  2010-08-28  No Especificado        19
# ...   ...      ...       ...         ...              ...       ...
# 8394  209     7765     55558  2010-08-09            Medio         8
# 8395  982     7766     55558  2010-08-09            Medio        23
# 8396  514     7906     56550  2011-04-08  No Especificado        37
# 8397  406     7907     56550  2011-04-08  No Especificado         8
# 8398  135     7914     56581  2009-02-08             Alto        20
#
#           Ventas  Descuento  Tipo de Envío   Ganancia  ...  \
# 0       261.5400       0.04  Aereo Regular  -213.2500  ...
# ...

# %%
print(DataFrame[:10]) # me muestra cierta cantidad de filas
# Out:
#    SKU  ID fila  ID Orden Fecha Orden        Prioridad  Cantidad      Ventas  \
# 0    1        1         3  2010-10-13             Bajo         6    261.5400
# 1    2       49       293  2012-10-01             Alto        49  10123.0200
# 2    3       50       293  2012-10-01             Alto        27    244.5700
# 3    4       80       483  2011-07-10             Alto        30   4965.7595
# 4    5       85       515  2010-08-28  No Especificado        19    394.2700
# 5    6       86       515  2010-08-28  No Especificado        21    146.6900
# 6    7       97       613  2011-06-17             Alto        12     93.5400
# 7    8       98       613  2011-06-17             Alto        22    905.0800
# 8    9      103       643  2011-03-24             Alto        21   2781.8200
# 9   10      107       678  2010-02-26             Bajo        44    228.4100
#
#    Descuento  Tipo de Envío   Ganancia  ...  Nombre del Cliente  Provincia  \
# ...

# %%
print(DataFrame[['Categoría de producto','Segmento del Cliente']])
# Out:
#      Categoría de producto Segmento del Cliente
# 0     Árticulos de Oficina                 PYME
# 1     Árticulos de Oficina           Consumidor
# 2     Árticulos de Oficina           Consumidor
# 3               Tecnología          Corporativo
# 4     Árticulos de Oficina           Consumidor
# ...                    ...                  ...
# 8394               Muebles           Consumidor
# 8395  Árticulos de Oficina           Consumidor
# 8396               Muebles     Oficina en Hogar
# 8397            Tecnología     Oficina en Hogar
# 8398               Muebles           Consumidor
#
# [8399 rows x 2 columns]

# %%
DataFrame2
# Out:
#       SKU Producto Categoría de producto Categoría de Subproducto  \
# 0                1  Árticulos de Oficina           Almacenamiento
# 1                2  Árticulos de Oficina             Linea Blanca
# 2                3  Árticulos de Oficina            Organizadores
# 3                4            Tecnología                Teléfonos
# 4                5  Árticulos de Oficina             Linea Blanca
# ...            ...                   ...                      ...
# 1284          1285               Muebles                 Libreros
# 1285          1286  Árticulos de Oficina            Organizadores
# 1286          1287               Muebles                   Sillas
# 1287          1288  Árticulos de Oficina                    Papel
# 1288          1289  Árticulos de Oficina            Plumas y Arte
#
#                                     Nombre del Producto  \
# 0      Eldon Base for stackable storage shelf, platinum
# 1     1.7 Cubic Foot Compact "Cube" Office Refrigera...
# ...
