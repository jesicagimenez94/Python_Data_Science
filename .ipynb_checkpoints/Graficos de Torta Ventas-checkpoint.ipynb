# %%
import pandas as pd

# %%
data=pd.ExcelFile(r'C:\Users\jesica\Downloads\Ventas+2010+-+copia.xlsx', engine='openpyxl') #agrego el archivo excel

# %%
DataFrame=data.parse('Datos')

# %%
DataFrame["Prioridad"].value_counts().plot(kind='pie', autopct='%.2f%%', title='Porcentaje de ventas por prioridad') #creamos grafico de torta

# %%
DataFrame["Segmento del Cliente"].value_counts().plot(kind='pie', autopct='%.2f%%', title='Porcentaje de ventas por segmento del cliente')
